# %%
import numpy as np
import pandas as pd

# %%
covid = pd.read_csv('covid_data.csv');

# %%
covid.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
covid.shape
# Out:
# (321, 6)

# %%
covid.count()

#Null values means missing values
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
covid.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(covid.isnull())
plt.show()

# %% [markdown]
# # Q) Show the number of Confirmed, Deaths and Recoveress cases in each Region.

# %%
covid.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid.groupby('Region').sum().head(20)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# Bahamas                     80      11         23
# Bahrain                   2921       8       1455
# Bangladesh                7103     163        150
# Barbados                    80       7         39
# Belarus                  13181      84       2072
# Belgium                  47859    7501      11283
# Belize                      18       2          9
# ...

# %%
covid.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20) #Sort data
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Q) Remove all the records where confirmed cases is Less than 10

# %%
covid.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid = covid[~(covid['Confirmed'] < 10)]
covid['Confirmed'].sort_values()
# Out:
# 156        10
# 70         10
# 59         10
# 318        11
# 217        11
# 256        11
# 144        11
# 27         11
# 306        12
# 118        13
# 215        13
# 206        13
# 270        14
# 136        15
# 138        16
# 45         16
# 201        16
# 114        16
# 137        17
# 260        18
# 16         18
# 55         18
# 281        18
# 90         19
# 64         20
# 21         23
# 5          24
# 163        24
# 279        27
# 4          27
#         ...
# 131     24505
# 47      24675
# 213     25775
# 282     26610
# 200     26767
# 303     27257
# 243     27660
# 158     29407
# 74      33062
# 208     33193
# 128     33931
# 116     38802
# 251     40399
# 278     46327
# 15      47859
# 195     48747
# 232     50358
# 249     60265
# 229     68128
# 22      79685
# 76      93657
# 134     99399
# 262    116365
# 167    117589
# 61     161539
# 57     165093
# 168    165221
# 80     203591
# 153    236899
# 265    299691
# ...

# %% [markdown]
# # Q) In Which Region, Maximum number of confirmed cases are recorded ?

# %%
covid.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
covid.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Brazil              79685
# Canada              52860
# Belgium             47859
# Netherlands         38993
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Q) In Which region, minimum deaths were recorded ?

# %%
covid.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid.groupby('Region')['Deaths'].sum().sort_values(ascending=True).head(50)
# Out:
# Region
# Cambodia                            0
# Seychelles                          0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# South Sudan                         0
# Rwanda                              0
# Grenada                             0
# Macau                               0
# Madagascar                          0
# Nepal                               0
# Namibia                             0
# Saint Vincent and the Grenadines    0
# Mozambique                          0
# Holy See                            0
# Timor-Leste                         0
# Mongolia                            0
# Uganda                              0
# Laos                                0
# Eritrea                             0
# Vietnam                             0
# Fiji                                0
# Dominica                            0
# Gambia                              1
# ...

# %% [markdown]
# # Q) How many Confirmed,Deaths & Recovered cases were reported from India till 29 April 2020 ?

# %%
covid.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid[covid['Region'] == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# # Q-a) Sort the entire data wrt No. of Confirmed cases in ascending order.

# %%
covid.sort_values(by=['Confirmed'],ascending=True).head(20)
# Out:
#           Date                        State                            Region  \
# 156  4/29/2020                          NaN                          Suriname
# 70   4/29/2020                          NaN                          Holy See
# 59   4/29/2020                          NaN                            Gambia
# 318  4/29/2020                        Yukon                            Canada
# 217  4/29/2020                    Greenland                           Denmark
# 256  4/29/2020                   Montserrat                                UK
# 144  4/29/2020                          NaN                        Seychelles
# 27   4/29/2020                          NaN                           Burundi
# 306  4/29/2020     Turks and Caicos Islands                                UK
# 118  4/29/2020                          NaN                         Nicaragua
# 215  4/29/2020               Grand Princess                            Canada
# ...

# %% [markdown]
# # Q-b) Sort the Entire data wrt No. of Recovered cases in descending order.

# %%
covid.sort_values(by=['Recovered'],ascending = False).head(20)
# Out:
#           Date  State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020    NaN           Spain     236899   24275     132929
# 61   4/29/2020    NaN         Germany     161539    6467     120400
# 76   4/29/2020    NaN            Iran      93657    5957      73791
# 80   4/29/2020    NaN           Italy     203591   27682      71252
# 229  4/29/2020  Hubei  Mainland China      68128    4512      63616
# 57   4/29/2020    NaN          France     165093   24087      48228
# 167  4/29/2020    NaN          Turkey     117589    3081      44040
# 22   4/29/2020    NaN          Brazil      79685    5513      34132
# 158  4/29/2020    NaN     Switzerland      29407    1716      22600
# 78   4/29/2020    NaN         Ireland      20253    1190      13386
# 8    4/29/2020    NaN         Austria      15402     580      12779
# 107  4/29/2020    NaN          Mexico      17799    1732      11423
# 15   4/29/2020    NaN         Belgium      47859    7501      11283
# ...
